# %%
import os 
import pandas as pd 
import numpy as np
import torch
from dfencoder import AutoEncoder
from pathlib import Path
import json
from sklearn.model_selection import train_test_split

# %% [markdown]
# Big Picture:
# - For the dfp pipeline (Training)
#     - Preproc
#     - dfp_rolling_window
#     - data prep
#     - monitor module
#     - dfp training module

# %%
def load_data(train_data_dir: Path):
    i = 0 
    all_data_dfs = []
    for a_td in train_data_dir.iterdir():
        with open(a_td,'r') as f: 
            json_obj = json.load(f)
        json_normalized = pd.json_normalize(json_obj)
        all_data_dfs.append(json_normalized)
    return all_data_dfs

# %%
azure_training_data = Path("data/azure-training-data")
azure_inference_data = Path("data/azure-inference-data")

# %%
azure_training_data_df_list = load_data(azure_training_data)
azure_inference_data_df_list = load_data(azure_inference_data)
#azure_training_data_df = pd.DataFrame(azure_training_data_json)
#azure_inference_data_df = pd.DataFrame(azure_inference_data_json)

# %%
# concat into one big dataframe for training and inference 

azure_training_df = pd.concat(azure_training_data_df_list)
azure_inference_df = pd.concat(azure_inference_data_df_list)

# %%
azure_training_df['properties.userDisplayName'].unique()
# Out:
# array(['Thomas Price', 'Attack Target', 'Aaron Cole', 'Joseph Taylor',
#        'Cynthia Perry', 'Alicia Ramirez', 'Jim Gonzalez',
#        'Cassie Fernandez', 'Jacob Meyers', 'Nicholas Black',
#        'Terry Proctor', 'Vanessa Ramirez', 'Keith Sheppard',
#        'Jamie Watson', 'Kristen Howell', 'David Johnson',
#        'Melissa Martin', 'Amy Anderson', 'Angela Kerr', 'Robert Rojas'],
#       dtype=object)

# %%
# split dataframe into user specific dfs
unique_names = list(azure_training_df['properties.userDisplayName'].unique())
training_data_dfs = {}
inference_data_dfs = {}
for name in unique_names: 
    name_azure_training_df = azure_training_df[azure_training_df['properties.userDisplayName'] == name]
    name_azure_inf_df = azure_inference_df[azure_inference_df['properties.userDisplayName'] == name]
    
    training_data_dfs[name] = name_azure_training_df
    inference_data_dfs[name] = name_azure_inf_df

# %%
for name, df in training_data_dfs.items(): 
    print('Name=', name)
    print('Training samples:', len(df))
    print('Inference samples', len(inference_data_dfs[name]))
# Out:
# Name= Thomas Price
# Training samples: 493
# Inference samples 32
# Name= Attack Target
# Training samples: 378
# Inference samples 124
# Name= Aaron Cole
# Training samples: 371
# Inference samples 28
# Name= Joseph Taylor
# Training samples: 300
# Inference samples 19
# Name= Cynthia Perry
# Training samples: 424
# Inference samples 26
# Name= Alicia Ramirez
# Training samples: 11
# Inference samples 0
# Name= Jim Gonzalez
# Training samples: 122
# Inference samples 8
# Name= Cassie Fernandez
# Training samples: 126
# Inference samples 12
# Name= Jacob Meyers
# Training samples: 123
# Inference samples 8
# Name= Nicholas Black
# Training samples: 10
# Inference samples 1
# Name= Terry Proctor
# Training samples: 124
# Inference samples 5
# Name= Vanessa Ramirez
# Training samples: 130
# Inference samples 5
# Name= Keith Sheppard
# Training samples: 117
# Inference samples 13
# Name= Jamie Watson
# Training samples: 119
# Inference samples 12
# Name= Kristen Howell
# Training samples: 120
# Inference samples 10
# Name= David Johnson
# Training samples: 122
# Inference samples 9
# Name= Melissa Martin
# Training samples: 118
# Inference samples 14
# Name= Amy Anderson
# Training samples: 10
# Inference samples 1
# Name= Angela Kerr
# Training samples: 11
# Inference samples 0
# Name= Robert Rojas
# Training samples: 10
# Inference samples 1

# %% [markdown]
# Feature Preprocessing

# %%
# feature_list_p = [
#     'appDisplayName',
#     'clientAppUsed',
#     'deviceDetail.displayName',
#     'deviceDetail.browser',
#     'deviceDetail.operatingSystem',
#     'statusFailureReason',
#     'riskEventTypes_v2',
#     'location.countryOrRegion',
#     'location.city',
# ]

feature_list_p = [
    'appDisplayName',
    'clientAppUsed',
    'deviceDetail.displayName',
    'deviceDetail.browser',
    'deviceDetail.operatingSystem',
    'status.failureReason',
    'location.countryOrRegion',
    'location.city',
]

# %%
cols = azure_training_df.columns
for p in feature_list_p: 
    for c in cols: 
        if p in c: 
            print(c)
# Out:
# properties.appDisplayName
# properties.clientAppUsed
# properties.deviceDetail.displayName
# properties.deviceDetail.browser
# properties.deviceDetail.operatingSystem
# properties.status.failureReason
# properties.location.countryOrRegion
# properties.location.city

# %%
feature_list = [('properties.' + f) for f in feature_list_p]

# %%
feature_list
# Out:
# ['properties.appDisplayName',
#  'properties.clientAppUsed',
#  'properties.deviceDetail.displayName',
#  'properties.deviceDetail.browser',
#  'properties.deviceDetail.operatingSystem',
#  'properties.status.failureReason',
#  'properties.location.countryOrRegion',
#  'properties.location.city']

# %%
for c in azure_training_df.columns:
    if 'riskEventTypesv2' in c: 
        print(c)

# %%
def convert_column_names(df):
    df.columns = [col.replace(".","_") for col in df.columns]
    return df

# %%
feat_processed_training_data_dfs = {}
feat_processed_inference_data_dfs = {}

for name, train_df in training_data_dfs.items():
    feat_proc_train_df = train_df[feature_list]
    feat_proc_train_df = feat_proc_train_df.drop('properties.deviceDetail.displayName',axis=1)
    feat_proc_train_df = convert_column_names(feat_proc_train_df)
    feat_processed_training_data_dfs[name] = feat_proc_train_df

for name, inf_df in inference_data_dfs.items():
    feat_proc_inf_df = inf_df[feature_list]
    feat_proc_inf_df = convert_column_names(feat_proc_inf_df)
    feat_processed_inference_data_dfs[name] = feat_proc_inf_df

# %%
def train_user_model(training_df,split_size=0.2):

    mps_device = torch.device("mps:0")
    # train test split
    train_df, val_df = train_test_split(training_df, test_size=split_size)

    num_columns = len(training_df.columns) 
    model = AutoEncoder(encoder_layers=[num_columns,int(num_columns/2)],
                        decoder_layers=[num_columns],
                        activation='relu',
                        swap_p=0.2,
                        lr=0.01,
                        batch_size=32,
                        optimizer='sgd',
                        scaler='gauss_rank',
                        min_cats=1,)
    
    model.fit(training_df,20,val_df)
    return model

# %%
user_models_by_name = {}
for name, df in feat_processed_training_data_dfs.items():
    model = train_user_model(df)
    user_models_by_name[name] = model
# Out:
# /Users/vgangal/jpmc_work/software/miniconda3/envs/syclone/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# 100%|██████████|
/s]
# 100%|██████████| 4/4 [00:00<00:00, 318.88it/s]
# 100%|██████████| 4/4 [00:00<00:00, 306.28it/s]
# 100%|██████████| 4/4 [00:00<00:00, 319.13it/s]
# 100%|██████████| 4/4 [00:00<00:00, 337.61it/s]
# 100%|██████████| 4/4 [00:00<00:00, 318.72it/s]
# 100%|██████████| 4/4 [00:00<00:00, 111.95it/s]
# 100%|██████████| 4/4 [00:00<00:00, 300.91it/s]
# 100%|██████████| 4/4 [00:00<00:00, 318.04it/s]
# 100%|██████████| 4/4 [00:00<00:00, 323.36it/s]
# 100%|██████████| 4/4 [00:00<00:00, 326.53it/s]
# 100%|██████████| 4/4 [00:00<00:00, 309.41it/s]
# /Users/vgangal/jpmc_work/software/miniconda3/envs/syclone/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# 100%|██████████| 1/1 [00:00<00:00, 432.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 441.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 446.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 434.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 437.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 408.84it/s]
# 100%|██████████| 1/1 [00:00<00:00, 443.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 401.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 495.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 430.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 408.84it/s]
# 100%|██████████| 1/1 [00:00<00:00, 393.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 456.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 414.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 443.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 416.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 414.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 398.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 467.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 391.66it/s]
# /Users/vgangal/jpmc_work/software/miniconda3/envs/syclone/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# 100%|██████████| 1/1 [00:00<00:00, 311.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 346.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 344.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 354.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 388.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 337.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 376.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 368.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 358.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 344.13it/s]
# 100%|██████████| 1/1 [00:00<00:00, 372.56it/s]
# 100%|██████████| 1/1 [00:00<00:00, 337.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 249.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 290.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 351.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 373.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 335.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 361.70it/s]
# 100%|██████████| 1/1 [00:00<00:00, 364.18it/s]
# 100%|██████████| 1/1 [00:00<00:00, 321.33it/s]
# /Users/vgangal/jpmc_work/software/miniconda3/envs/syclone/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# 100%|██████████| 1/1 [00:00<00:00, 387.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 428.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 439.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 423.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 428.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 424.78it/s]
# 100%|██████████| 1/1 [00:00<00:00, 441.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 441.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 438.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 409.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 478.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 464.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 479.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 403.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 427.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 407.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 420.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 384.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 432.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 425.69it/s]

# %%
def inference(model,df):
    anomaly_scores = model.get_anomaly_score(df)
    return anomaly_scores

# %%
# implement digital fingerprinting code / implement the actual pipeline
# feat_processed_inference_data_dfs
# for name, df  in feat_processed_inference_data_dfs: 
#     model = user_models_by_name[name]
#     anomaly_scores =

# %%
tp_inf_data = feat_processed_inference_data_dfs['Thomas Price']

# %%
model = user_models_by_name['Thomas Price']
ae_anomaly_score = model.get_anomaly_score(tp_inf_data)
tp_inf_data['anomaly_score'] = ae_anomaly_score
# Out:
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/699009138.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tp_inf_data['anomaly_score'] = ae_anomaly_score

# %%
tp_inf_data
# Out:
#     properties_appDisplayName         properties_clientAppUsed  \
# 3   Adobe Identity Management  Mobile Apps and Desktop clients
# 6   Adobe Identity Management  Mobile Apps and Desktop clients
# 9   Adobe Identity Management  Mobile Apps and Desktop clients
# 17           Cisco AnyConnect  Mobile Apps and Desktop clients
# 10           Cisco AnyConnect  Mobile Apps and Desktop clients
# 15           Cisco AnyConnect  Mobile Apps and Desktop clients
# 0   Adobe Identity Management  Mobile Apps and Desktop clients
# 2   Adobe Identity Management  Mobile Apps and Desktop clients
# 6   Adobe Identity Management  Mobile Apps and Desktop clients
# 19  Adobe Identity Management  Mobile Apps and Desktop clients
# 3   Adobe Identity Management  Mobile Apps and Desktop clients
# 12  Adobe Identity Management  Mobile Apps and Desktop clients
# 2            Cisco AnyConnect  Mobile Apps and Desktop clients
# 7   Adobe Identity Management  Mobile Apps and Desktop clients
# 15  Adobe Identity Management  Mobile Apps and Desktop clients
# 17                    SD ECDN                          Browser
# 6   Adobe Identity Management  Mobile Apps and Desktop clients
# 9            Cisco AnyConnect  Mobile Apps and Desktop clients
# 2   Adobe Identity Management  Mobile Apps and Desktop clients
# 10           Cisco AnyConnect  Mobile Apps and Desktop clients
# 15  Adobe Identity Management  Mobile Apps and Desktop clients
# 18                    Bipsync  Mobile Apps and Desktop clients
# 1            Cisco AnyConnect  Mobile Apps and Desktop clients
# 3   Adobe Identity Management  Mobile Apps and Desktop clients
# 4   Adobe Identity Management  Mobile Apps and Desktop clients
# 24  Adobe Identity Management  Mobile Apps and Desktop clients
# 4   Adobe Identity Management  Mobile Apps and Desktop clients
# 7   Adobe Identity Management  Mobile Apps and Desktop clients
# 7   Adobe Identity Management  Mobile Apps and Desktop clients
# 18  Adobe Identity Management  Mobile Apps and Desktop clients
# 20           Cisco AnyConnect  Mobile Apps and Desktop clients
# 23  Adobe Identity Management  Mobile Apps and Desktop clients
#
#    properties_deviceDetail_displayName properties_deviceDetail_browser  \
# 3                       THOMASPRICE-LT                  Edge 118.12158
# 6                       THOMASPRICE-LT                  Edge 118.12158
# 9                       THOMASPRICE-LT                  Edge 118.12158
# 17                      THOMASPRICE-LT                  Edge 118.12158
# 10                      THOMASPRICE-LT                  Edge 118.12158
# 15                      THOMASPRICE-LT                  Edge 118.12158
# 0                       THOMASPRICE-LT                  Edge 118.12158
# 2                       THOMASPRICE-LT                  Edge 118.12158
# 6                       THOMASPRICE-LT                  Edge 118.12158
# 19                      THOMASPRICE-LT                  Edge 118.12158
# 3                       THOMASPRICE-LT                  Edge 118.12158
# 12                      THOMASPRICE-LT                  Edge 118.12158
# 2                       THOMASPRICE-LT                   Edge 14.12206
# 7                       THOMASPRICE-LT                  Edge 118.12158
# 15                      THOMASPRICE-LT                  Edge 118.12158
# 17                      THOMASPRICE-LT        Rich Client 3.19.8.16603
# 6                       THOMASPRICE-LT                  Edge 118.12158
# 9                       THOMASPRICE-LT                  Edge 118.12158
# 2                       THOMASPRICE-LT                  Edge 118.12158
# 10                      THOMASPRICE-LT                  Edge 118.12158
# 15                      THOMASPRICE-LT                  Edge 118.12158
# 18                                 NaN                             NaN
# 1                       THOMASPRICE-LT                  Edge 118.12158
# 3                       THOMASPRICE-LT                  Edge 118.12158
# 4                       THOMASPRICE-LT                  Edge 118.12158
# 24                      THOMASPRICE-LT                  Edge 118.12158
# 4                       THOMASPRICE-LT                  Edge 118.12158
# 7                       THOMASPRICE-LT                  Edge 118.12158
# 7                       THOMASPRICE-LT                  Edge 118.12158
# 18                      THOMASPRICE-LT                  Edge 118.12158
# 20                      THOMASPRICE-LT                  Edge 118.12158
# 23                      THOMASPRICE-LT                  Edge 118.12158
#
#    properties_deviceDetail_operatingSystem  \
# 3                               Windows 10
# 6                               Windows 10
# 9                               Windows 10
# 17                              Windows 10
# 10                              Windows 10
# 15                              Windows 10
# 0                               Windows 10
# 2                               Windows 10
# 6                               Windows 10
# 19                              Windows 10
# 3                               Windows 10
# 12                              Windows 10
# 2                               Windows 10
# 7                               Windows 10
# 15                              Windows 10
# 17                              Windows 10
# 6                               Windows 10
# 9                               Windows 10
# 2                               Windows 10
# 10                              Windows 10
# 15                              Windows 10
# 18                                 Android
# 1                               Windows 10
# 3                               Windows 10
# 4                               Windows 10
# 24                              Windows 10
# 4                               Windows 10
# 7                               Windows 10
# 7                               Windows 10
# 18                              Windows 10
# 20                              Windows 10
# 23                              Windows 10
#
#                    properties_status_failureReason  \
# 3   External security challenge was not satisfied.
# 6   External security challenge was not satisfied.
# 9                                            Other
# 17  External security challenge was not satisfied.
# 10  External security challenge was not satisfied.
# 15  External security challenge was not satisfied.
# 0   External security challenge was not satisfied.
# 2   External security challenge was not satisfied.
# 6   External security challenge was not satisfied.
# 19  External security challenge was not satisfied.
# 3   External security challenge was not satisfied.
# 12  External security challenge was not satisfied.
# 2   External security challenge was not satisfied.
# 7   External security challenge was not satisfied.
# 15  External security challenge was not satisfied.
# 17                                             NaN
# 6   External security challenge was not satisfied.
# 9   External security challenge was not satisfied.
# 2   External security challenge was not satisfied.
# 10  External security challenge was not satisfied.
# 15  External security challenge was not satisfied.
# 18                                             NaN
# 1   External security challenge was not satisfied.
# 3   External security challenge was not satisfied.
# 4   External security challenge was not satisfied.
# 24  External security challenge was not satisfied.
# 4   External security challenge was not satisfied.
# 7   External security challenge was not satisfied.
# 7   External security challenge was not satisfied.
# 18  External security challenge was not satisfied.
# 20  External security challenge was not satisfied.
# 23  External security challenge was not satisfied.
#
#    properties_location_countryOrRegion properties_location_city  anomaly_score
# 3                                   XQ                 Brownton       0.844241
# 6                                   XR          Port Denisetown       0.300431
# 9                                   XR        Port Kimberlytown       0.758053
# 17                                  XN              Littlemouth       0.526056
# 10                                  XQ                 Brownton       0.857953
# 15                                  XR            Santosborough       0.505617
# 0                                   XN              Littlemouth       0.248657
# 2                                   XN              Littlemouth       0.248657
# 6                                   XR          Port Denisetown       0.300431
# 19                                  XR            Santosborough       0.372359
# 3                                   XN              Littlemouth       0.248657
# 12                                  XN              Littlemouth       0.248657
# 2                                   XR                 Kevinton       1.046799
# 7                                   XR                 Kevinton       0.418678
# 15                                  XR          Port Denisetown       0.300431
# 17                                  XQ          Veronicachester       1.784105
# 6                                   XR          Port Denisetown       0.300431
# 9                                   XN              Littlemouth       0.526056
# 2                                   XR          Port Denisetown       0.300431
# 10                                  XR          Port Denisetown       0.469714
# 15                                  XR          Port Denisetown       0.300431
# 18                                  XQ             Herringburgh       1.779849
# 1                                   XR            Santosborough       0.505617
# 3                                   XR          Port Denisetown       0.300431
# 4                                   XN              Littlemouth       0.248657
# 24                                  XR          Port Denisetown       0.300431
# 4                                   XR          Port Denisetown       0.300431
# 7                                   XR                 Kevinton       0.418678
# 7                                   XR            Santosborough       0.372359
# 18                                  XN              Littlemouth       0.248657
# 20                                  XR            Santosborough       0.505617
# 23                                  XR          Port Denisetown       0.300431

# %%
tp_inf_data.sort_values('anomaly_score',ascending=False).head(10)
tp_inf_data["zscore"] = (tp_inf_data["anomaly_score"] - tp_inf_data["anomaly_score"].mean())/tp_inf_data["anomaly_score"].std()
# Out:
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2706626964.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tp_inf_data["zscore"] = (tp_inf_data["anomaly_score"] - tp_inf_data["anomaly_score"].mean())/tp_inf_data["anomaly_score"].std()

# %%
# anomalous events 

tp_inf_data[tp_inf_data['zscore']> 2]
# Out:
#    properties_appDisplayName         properties_clientAppUsed  \
# 17                   SD ECDN                          Browser
# 18                   Bipsync  Mobile Apps and Desktop clients
#
#    properties_deviceDetail_displayName properties_deviceDetail_browser  \
# 17                      THOMASPRICE-LT        Rich Client 3.19.8.16603
# 18                                 NaN                             NaN
#
#    properties_deviceDetail_operatingSystem properties_status_failureReason  \
# 17                              Windows 10                             NaN
# 18                                 Android                             NaN
#
#    properties_location_countryOrRegion properties_location_city  \
# 17                                  XQ          Veronicachester
# 18                                  XQ             Herringburgh
#
#     anomaly_score    zscore
# 17       1.784105  3.274581
# 18       1.779849  3.263678

# %%
anomaly_tracker = {}
for name, df  in feat_processed_inference_data_dfs.items(): 
    model = user_models_by_name[name]
    anomaly_scores = model.get_anomaly_score(df)
    #print('anomaly len=',len(anomaly_scores))
    df['anomaly_score'] = anomaly_scores
    df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
    anomaly = df[df['zscore']>2]
    anomaly_tracker[name] = anomaly
# Out:
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['anomaly_score'] = anomaly_scores
# /var/folders/zc/6mjfb52x73qf5c6y554p68l40000gn/T/ipykernel_36976/2372849195.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["zscore"] = (df["anomaly_score"] - df["anomaly_score"].mean())/df["anomaly_score"].std()

# %%
anomaly_tracker['Aaron Cole']
# Out:
#                        properties_appDisplayName  \
# 3  Google Cloud / G Suite Connector by Microsoft
#
#           properties_clientAppUsed properties_deviceDetail_displayName  \
# 3  Mobile Apps and Desktop clients                                 NaN
#
#   properties_deviceDetail_browser properties_deviceDetail_operatingSystem  \
# 3                   Edge 99.14477                              Windows 10
#
#                      properties_status_failureReason  \
# 3  Fresh auth token is needed. Have the user re-s...
#
#   properties_location_countryOrRegion properties_location_city  anomaly_score  \
# 3                                  XD              Carrollstad       1.840238
#
#     zscore
# 3  2.78305

# %%
anomaly_tracker['Thomas Price']
# Out:
#    properties_appDisplayName         properties_clientAppUsed  \
# 17                   SD ECDN                          Browser
# 18                   Bipsync  Mobile Apps and Desktop clients
#
#    properties_deviceDetail_displayName properties_deviceDetail_browser  \
# 17                      THOMASPRICE-LT        Rich Client 3.19.8.16603
# 18                                 NaN                             NaN
#
#    properties_deviceDetail_operatingSystem properties_status_failureReason  \
# 17                              Windows 10                             NaN
# 18                                 Android                             NaN
#
#    properties_location_countryOrRegion properties_location_city  \
# 17                                  XQ          Veronicachester
# 18                                  XQ             Herringburgh
#
#     anomaly_score    zscore
# 17       1.784105  3.274581
# 18       1.779849  3.263678
